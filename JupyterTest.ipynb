# %% [markdown]
# #Top Level
# ##Second
# Hello this

# %%
# %matplotlib notebook
print("I'm writing a string")
import matplotlib.pyplot as plt

plt.plot([[1,1],[2,2]])
# Out:
# I'm writing a string
# <img src="data:image/png;base64,..." width="640">
# ...

# %% [markdown]
# 'This is text'
